# %%
import cv2 
import dlib 
from scipy.spatial import distance
from imutils import face_utils
import pyttsx3
import keyboard
from time import sleep

flag = False
count=0
blink=0
select1=0
a = ''

cap = cv2.VideoCapture(0)

engine = pyttsx3.init()

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

def eye_aspect_ratio(eye):
    A = distance.euclidean(eye[1], eye[5])
    B = distance.euclidean(eye[2], eye[4])

    C = distance.euclidean(eye[0], eye[3])
    eye = (A + B) / (2.0 * C)

    return eye

while True:
    img1=cv2.imread('background.jpg')
    img1 = cv2.resize(img1, (600, 600))
    success,img = cap.read()
    imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = detector(imgGray)



    for face in faces:
        landmarks = predictor(imgGray,face)

        landmarks = face_utils.shape_to_np(landmarks)

        
        leftEye = landmarks[42:48]
        rightEye = landmarks[36:42]

        for i in leftEye:
            cv2.circle(img, (i), 2, (255,255,255), thickness=1)
        for i in rightEye:
            cv2.circle(img, (i), 2, (255,255,255), thickness=1)

        leftEye = eye_aspect_ratio(leftEye)
        rightEye = eye_aspect_ratio(rightEye)

        eye = ((leftEye + rightEye) / 2.0)

        if eye<0.3:
            count+=1
            #print('count: ',count)
        else:

            if count>=4:
                blink+=1

            count=0

        cv2.putText(img, "Blink Count: {}".format(blink), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    cv2.putText(img1, 'MENU LIST', (10, 50),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    if select1>0 and select1<30:
        cv2.putText(img1, '1. chappathi <--', (10, 100),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            a = 'chappathi'
            print('Selected chapathi')

    else:
        cv2.putText(img1, '1. chappathi ', (10, 100),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    if select1>30 and select1<60:
        cv2.putText(img1, '2. Dosaai <--', (10, 150),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('selected Dosai')
    else:
        cv2.putText(img1, '2. Dosaai ', (10, 150),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    if select1>60 and select1<90:
        cv2.putText(img1, '3. Noodle <--', (10, 200),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('selected Noodles')
    else:
        cv2.putText(img1, '3. Noodle', (10, 200),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)


    if select1>90 and select1<120:
        cv2.putText(img1, '4. 4th option <--', (10, 250),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('selected 4th option')
    else:
        cv2.putText(img1, '4. 4th option', (10, 250),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
    if select1>120 and select1<150:
        cv2.putText(img1, '5. 5th option <--', (10, 300),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('Selected 5th option')
    else:
        cv2.putText(img1, '5. 5th option ', (10, 300),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    if select1>150 and select1<180:
        cv2.putText(img1, '6. 6th option <--', (10, 350),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('6th option')
    else:
        cv2.putText(img1, '6. 6th option ', (10, 350),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    if select1>180 and select1<210:
        cv2.putText(img1, '7. 7th option <--', (10, 400),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('selected 7th option')
    else:
        cv2.putText(img1, '7. 7th option', (10, 400),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)


    if select1>210 and select1<240:
        cv2.putText(img1, '8. 8th option <--', (10, 450),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            print('selected 8th option')
    else:
        cv2.putText(img1, '8. 8th option', (10, 450),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
    if select1>240 and select1<270:
        cv2.putText(img1, '9. 9th option <--', (10, 500),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            a = '9th option'
            print('selected 9th option')

    else:
        cv2.putText(img1, '9. 9th option', (10, 500),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)


    if select1>270 and select1<300:
        cv2.putText(img1, '10. Keyboard <--', (10, 550),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        if blink==1:
            flag = True
            print('selected Keyboard')
            break
            
                
    else:
        cv2.putText(img1, '10. 10th option', (10, 550),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)



    blink=0
    select1+=1
    if select1>305:
        select1=0
    
    if a == 'chappathi':
        chappathi = cv2.imread('fan.png')
        small_img = cv2.resize(chappathi,(200,200))

        x_offset = 350
        y_offset = 180

        x_end = x_offset + small_img.shape[1]
        y_end = y_offset + small_img.shape[0]

        img1[y_offset:y_end,x_offset:x_end] = small_img
        
        
        
    cv2.imshow('layout', img1)
    cv2.imshow('video',img)
    
    if a == 'chappathi':
        for i in range(10000):
            sleep(1)
            if keyboard.is_pressed("esc"):
                break
            else:
                engine.say('Selected chapathi')
                engine.runAndWait()
    
    keyboard_input = cv2.waitKey(1)
    if keyboard_input == 27:
        break


cap.release()
cv2.destroyAllWindows()

#######################################################################################################################

import cv2 
import dlib 
from scipy.spatial import distance
from imutils import face_utils
import pyttsx3
import keyboard
from time import sleep


engine = pyttsx3.init()

img=cv2.imread('background.jpg')
img = cv2.resize(img, (670, 600))

count=0
blink=0
select = 0
sent = ''

cap = cv2.VideoCapture(0)

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

def eye_aspect_ratio(eye):
    A = distance.euclidean(eye[1], eye[5])
    B = distance.euclidean(eye[2], eye[4])

    C = distance.euclidean(eye[0], eye[3])
    eye = (A + B) / (2.0 * C)

    return eye

while flag:
    success,img1 = cap.read()
    imgGray = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
    faces = detector(imgGray)



    for face in faces:
        landmarks = predictor(imgGray,face)

        landmarks = face_utils.shape_to_np(landmarks)

        
        leftEye = landmarks[42:48]
        rightEye = landmarks[36:42]

        for i in leftEye:
            cv2.circle(img1, (i), 2, (255,255,255), thickness=1)
        for i in rightEye:
            cv2.circle(img1, (i), 2, (255,255,255), thickness=1)

        leftEye = eye_aspect_ratio(leftEye)
        rightEye = eye_aspect_ratio(rightEye)

        eye = ((leftEye + rightEye) / 2.0)

        if eye<0.3:
            count+=1
            #print('count: ',count)
        else:

            if count>=3:
                blink+=1
                cv2.putText(img1, "Blink", (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

            count=0
    
    if select > 0 and select < 50:
        cv2.rectangle(img, (0,0), (60,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'A', (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'A'
    else:
        cv2.rectangle(img, (0,0), (60,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'A', (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
    
    
    if select > 50 and select < 100:
        cv2.rectangle(img, (60,0), (120,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'B', (70,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'B'
    else:    
        cv2.rectangle(img, (60,0), (120,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'B', (70,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 100 and select < 150:
        cv2.rectangle(img, (120,0), (180,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'C', (130,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'C'
    else:
        cv2.rectangle(img, (120,0), (180,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'C', (130,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 150 and select < 200:
        cv2.rectangle(img, (180,0), (240,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'D', (190,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'D'
    else:
        cv2.rectangle(img, (180,0), (240,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'D', (190,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 200 and select < 250:
        cv2.rectangle(img, (240,0), (300,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'E', (250,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'E'
    else:
        cv2.rectangle(img, (240,0), (300,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'E', (250,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 250 and select < 300:
        cv2.rectangle(img, (300,0), (360,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'F', (310,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'F'
    else:
        cv2.rectangle(img, (300,0), (360,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'F', (310,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 300 and select < 350:
        cv2.rectangle(img, (360,0), (420,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'G', (370,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'G'
    else:
        cv2.rectangle(img, (360,0), (420,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'G', (370,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 350 and select < 400:
        cv2.rectangle(img, (420,0), (480,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'H', (430,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'H'
    else:
        cv2.rectangle(img, (420,0), (480,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'H', (430,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 400 and select < 450:
        cv2.rectangle(img, (480,0), (540,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'I', (490,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'I'
    else:
        cv2.rectangle(img, (480,0), (540,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'I', (490,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 450 and select < 500:
        cv2.rectangle(img, (540,0), (670,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'SELECT', (550,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            print('blink')
            for i in range(1000000):
                print(i)
                if keyboard.is_pressed("q"):
                    break
                elif i %1000 == 0:
                    engine.say(sent)
                    engine.runAndWait()
    else:
        cv2.rectangle(img, (540,0), (670,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'SELECT', (550,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 500 and select < 550:
        cv2.rectangle(img, (0,80), (60,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'J', (10,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'J'
    else:
        cv2.rectangle(img, (0,80), (60,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'J', (10,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 550 and select < 600:
        cv2.rectangle(img, (60,80), (120,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'K', (70,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'K'
    else:
        cv2.rectangle(img, (60,80), (120,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'K', (70,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 600 and select < 650:
        cv2.rectangle(img, (120,80), (180,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'L', (130,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'L'
    else:
        cv2.rectangle(img, (120,80), (180,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'L', (130,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 650 and select < 700:
        cv2.rectangle(img, (180,80), (240,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'M', (190,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'M'
    else:
        cv2.rectangle(img, (180,80), (240,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'M', (190,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 700 and select < 750:
        cv2.rectangle(img, (240,80), (300,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'N', (250,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'N'
    else:
        cv2.rectangle(img, (240,80), (300,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'N', (250,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 750 and select < 800:
        cv2.rectangle(img, (300,80), (360,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'O', (310,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'O'
    else:
        cv2.rectangle(img, (300,80), (360,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'O', (310,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 800 and select < 850:
        cv2.rectangle(img, (360,80), (420,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'P', (370,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'P'
    else:
        cv2.rectangle(img, (360,80), (420,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'P', (370,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 850 and select < 900:
        cv2.rectangle(img, (420,80), (480,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'Q', (430,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'Q'
    else:
        cv2.rectangle(img, (420,80), (480,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'Q', (430,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 900 and select < 950:
        cv2.rectangle(img, (480,80), (540,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'R', (490,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'R'
    else:
        cv2.rectangle(img, (480,80), (540,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'R', (490,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 950 and select < 1000:
        cv2.rectangle(img, (540,80), (600,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'S', (550,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'S'
    else:
        cv2.rectangle(img, (540,80), (600,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'S', (550,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1000 and select < 1050:
        cv2.rectangle(img, (600,80), (670,40), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'T', (610,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'T'
    else:
        cv2.rectangle(img, (600,80), (670,40), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'T', (610,70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1050 and select < 1100:
        cv2.rectangle(img, (0,120), (60,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'U', (10,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'U'
    else:
        cv2.rectangle(img, (0,120), (60,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'U', (10,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1100 and select < 1150:
        cv2.rectangle(img, (60,120), (120,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'V', (70,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'V'
    else:
        cv2.rectangle(img, (60,120), (120,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'V', (70,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1150 and select < 1200:
        cv2.rectangle(img, (120,120), (180,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'W', (130,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'W'
    else:
        cv2.rectangle(img, (120,120), (180,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'W', (130,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

    if select > 1200 and select < 1250:
        cv2.rectangle(img, (180,120), (240,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'X', (190,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'X'
    else:
        cv2.rectangle(img, (180,120), (240,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'X', (190,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1250 and select < 1300:
        cv2.rectangle(img, (240,120), (300,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'Y', (250,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'Y'
    else:
        cv2.rectangle(img, (240,120), (300,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'Y', (250,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
    if select > 1300 and select < 1350:
        cv2.rectangle(img, (300,120), (360,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'Z', (310,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += 'Z'
    else:
        cv2.rectangle(img, (300,120), (360,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'Z', (310,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        
    
    if select > 1350 and select < 1400:
        cv2.rectangle(img, (360,120), (470,80), (255,255,255), thickness=cv2.FILLED)
        cv2.putText(img, 'space', (370,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        if blink == 1:
            sent += ' '
    else:
        cv2.rectangle(img, (360,120), (470,80), (50,50,50), thickness=cv2.FILLED)
        cv2.putText(img, 'space', (370,110), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
        
        
    
        


    cv2.putText(img, sent[:29], (50,210), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
    if len(sent) >= 60:
        cv2.putText(img, sent[60:], (50,290), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)
    elif len(sent) >= 30:
        cv2.putText(img, sent[30:59], (50,250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255),2)

        
        
    blink=0
    select+=1
    if select>1400:
        select=0
    cv2.imshow('layout', img)
    cv2.imshow('video',img1)
    keyboard_input = cv2.waitKey(1)
    if keyboard_input == 27:
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# selected 4th option
# selected 4th option
# Selected 5th option
# Selected 5th option
# Selected 5th option
# 6th option
# selected 7th option
# selected 7th option
# selected 8th option
# selected Keyboard
